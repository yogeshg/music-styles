# %%
import models as m
# Out:
# Using TensorFlow backend.

# %%
reload(m)
# Out:
# <module 'models' from 'models.pyc'>

# %%
embeddings_path = '../data2/chord2vec_30hr.npz'
m.load_embeddings(embeddings_path=embeddings_path)

# %%
import logging

# %%
logging.getLogger('models').setLevel(logging.DEBUG)

# %%
m.load_data(x_datapath='../data/X.pickle', y_datapath='../data/y.pickle')
# Out:
# 2017-05-06 22:46:56,788:DEBUG:models:MainThread:line 237: loading data from: ../data/X.pickle
# 2017-05-06 22:48:33,294:DEBUG:models:MainThread:line 240: loading labels from: ../data/y.pickle
# 2017-05-06 22:48:33,358:INFO:root:MainThread:line 261: two most common: [('Pop_Rock\n', 20985), ('Electronic\n', 3458)]
# 2017-05-06 22:48:33,359:INFO:root:MainThread:line 262: two most common: ['Pop_Rock\n', 'Electronic\n']
# 2017-05-06 22:48:33,366:DEBUG:models:MainThread:line 207: ['Pop_Rock\n', 'Electronic\n']
# 2017-05-06 22:48:33,368:DEBUG:models:MainThread:line 208: Counter({'Pop_Rock\n': 13530, 'Electronic\n': 2281})
# 2017-05-06 22:48:33,369:DEBUG:models:MainThread:line 209: 2281
# 2017-05-06 22:48:33,370:DEBUG:models:MainThread:line 214: Counter({'Pop_Rock\n': 2281, 'Electronic\n': 2281})
# 2017-05-06 22:48:33,386:DEBUG:models:MainThread:line 207: ['Pop_Rock\n', 'Electronic\n']
# ...

# %%
# m.load_data(x_datapath='../data/X.001.pickle', y_datapath='../data/y.001.pickle')

# %%
logging.getLogger('models').setLevel(logging.INFO)

# %%
print len(m.train), len(m.y_train)
print len(m.valid), len(m.y_valid)
print len(m.test), len(m.y_test)
# Out:
# 4562 4562
# 1200 1200
# 1154 1154

# %%
# m.np.savez('../data/cached_sets_20170506',
#            train=m.train, y_train=m.y_train,
#            valid=m.valid, y_valid=m.y_valid,
#            test=m.test, y_test=m.y_test)

# %%
# m.load_data_cached('../data/cached_sets_20170506.npz')

# %%
def f(**kwargs):
    print kwargs
    
def r1():
    use_embeddings = True
    use_embeddings=True
    dilated_convs=False
    filter_sizes=range(1,4)
    num_filters=50
    use_batch_normalization=True
    pooling='max'
    m.run_experiment(**locals())
    
def r2():
    use_embeddings = True
    use_embeddings=True
    dilated_convs=False
    filter_sizes=range(1,4)
    num_filters=500
    use_batch_normalization=True
    pooling='max'
    m.run_experiment(**locals())

# %%
r1()
# Out:
# 2017-05-06 15:11:33,681:INFO:models:MainThread:line 318: created a DataManager for batch_size: 256, maxepochs: 5001, num_batches: 18
# 2017-05-06 15:11:33,682:INFO:models:MainThread:line 318: created a DataManager for batch_size: 256, maxepochs: 5001, num_batches: 5
# 2017-05-06 15:11:33,684:INFO:models:MainThread:line 318: created a DataManager for batch_size: 256, maxepochs: 5001, num_batches: 5
# 2017-05-06 15:11:35,166:INFO:models:MainThread:line 391: starting training
# 2017-05-06 15:11:35,169:INFO:models:MainThread:line 392: (18, 5)
# Epoch 1/50
# 18/18 [==============================] - 655s - loss: 2.7609 - categorical_accuracy: 0.0873 - val_loss: 2.4371 - val_categorical_accuracy: 0.5008
# Epoch 2/50
# 18/18 [==============================] - 649s - loss: 1.6779 - categorical_accuracy: 0.4454 - val_loss: 1.8046 - val_categorical_accuracy: 0.5000
# Epoch 4/50
# ...

# %%
def r3():
    use_embeddings = True
    use_embeddings=False
    dilated_convs=False
    filter_sizes=range(1,4)
    num_filters=50
    use_batch_normalization=True
    pooling='flatten'
    m.run_experiment(**locals())
    return

r3()
# Out:
# 2017-05-06 21:08:22,504:INFO:models:MainThread:line 318: created a DataManager for batch_size: 256, maxepochs: 5001, num_batches: 18
# 2017-05-06 21:08:22,506:INFO:models:MainThread:line 318: created a DataManager for batch_size: 256, maxepochs: 5001, num_batches: 5
# 2017-05-06 21:08:22,507:INFO:models:MainThread:line 318: created a DataManager for batch_size: 256, maxepochs: 5001, num_batches: 5
# 2017-05-06 21:08:23,404:INFO:models:MainThread:line 391: starting training
# 2017-05-06 21:08:23,407:INFO:models:MainThread:line 392: (18, 5)
# Epoch 1/50
# 18/18 [==============================] - 143s - loss: 2.3735 - categorical_accuracy: 0.3545 - val_loss: 3.3355 - val_categorical_accuracy: 0.0000e+00
# Epoch 2/50
# 18/18 [==============================] - 114s - loss: 1.8054 - categorical_accuracy: 0.4965 - val_loss: 2.5526 - val_categorical_accuracy: 0.0000e+00
# Epoch 3/50
# ...

# %%
def r4():
    use_embeddings = True
    use_embeddings=True
    dilated_convs=False
    filter_sizes=range(1,10)
    num_filters=50
    use_batch_normalization=True
    pooling='max'
    m.run_experiment(**locals())
    
r4()
# Out:
# 2017-05-06 22:39:42,496:INFO:models:MainThread:line 318: created a DataManager for batch_size: 256, maxepochs: 5001, num_batches: 18
# 2017-05-06 22:39:42,497:INFO:models:MainThread:line 318: created a DataManager for batch_size: 256, maxepochs: 5001, num_batches: 5
# 2017-05-06 22:39:42,498:INFO:models:MainThread:line 318: created a DataManager for batch_size: 256, maxepochs: 5001, num_batches: 5
# 2017-05-06 22:39:43,891:INFO:models:MainThread:line 391: starting training
# 2017-05-06 22:39:43,894:INFO:models:MainThread:line 392: (18, 5)
# Epoch 1/50
#  2/18 [==>...........................] - ETA: 2407s - loss: 2.9559 - categorical_accuracy: 0.0488

# %%
def r5():
    use_embeddings = True
    use_embeddings=True
    dilated_convs=False
    filter_sizes=range(1,4)
    num_filters=50
    use_batch_normalization=True
    pooling='avg'
    m.run_experiment(**locals())

r5()
# Out:
# 2017-05-06 22:53:02,834:INFO:models:MainThread:line 318: created a DataManager for batch_size: 128, maxepochs: 5001, num_batches: 36
# 2017-05-06 22:53:02,835:INFO:models:MainThread:line 318: created a DataManager for batch_size: 128, maxepochs: 5001, num_batches: 10
# 2017-05-06 22:53:02,837:INFO:models:MainThread:line 318: created a DataManager for batch_size: 128, maxepochs: 5001, num_batches: 10
# 2017-05-06 22:53:03,812:INFO:models:MainThread:line 391: starting training
# 2017-05-06 22:53:03,814:INFO:models:MainThread:line 392: (36, 10)
# Epoch 1/50
# 36/36 [==============================] - 879s - loss: 2.2358 - categorical_accuracy: 0.2391 - val_loss: 2.3949 - val_categorical_accuracy: 0.5742
# Epoch 2/50
# 36/36 [==============================] - 706s - loss: 1.4214 - categorical_accuracy: 0.4813 - val_loss: 2.0436 - val_categorical_accuracy: 0.5408
# Epoch 3/50
# 35/36 [============================>.] - ETA: 20s - loss: 0.9807 - categorical_accuracy: 0.4873

# %%
40+2
